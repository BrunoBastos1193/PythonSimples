# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.3.2'

# %%
arr = np.array([1, 2, 3, 4, 5])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
soma = arr + 10
print("Array após somar 10: ", soma)
# Out:
# Array após somar 10:  [11 12 13 14 15]

# %%
multiplicar = arr * 2
print("Array após multiplicar por 2", multiplicar)
# Out:
# Array após multiplicar por 2 [ 2  4  6  8 10]

# %%
media = np.mean(arr)
print('Média do array:', media)
# Out:
# Média do array: 3.0
